# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Colab Notebooks/Artificial NN & Deep Learning/Assignment 1
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/Colab Notebooks/Artificial NN & Deep Learning/Assignment 1

# %%
# !pip install  keras-cv tensorflow
# !pip install  keras-cv tensorflow
# !pip install  keras
# Out:
# Collecting keras-cv
#   Using cached keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Collecting keras-core (from keras-cv)
#   Using cached keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Using cached keras_cv-0.9.0-py3-none-any.whl (650 kB)
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 49.7 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0
# Requirement already satisfied: keras-cv in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv) (24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras-cv) (4.9.7)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.1.7)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras-cv) (0.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras-cv) (4.66.6)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (1.16.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras-cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (1.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras-cv) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras-cv) (0.16)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from keras_cv.layers import RandomSaturation
from keras_cv.layers import RandomSharpness
from keras_cv.layers import RandomShear
from keras_cv.layers import Solarization
from keras_cv.layers import Augmenter

# %%
file_path = 'Clean_Dataset.npz'

with np.load(file_path) as data:
    training_images = data['images'] #/ 255.0
    training_labels = data['labels']

# Check
print(f"Shape of images: {training_images.shape}")
print(f"type of images: {type(training_images)}")
print(f"shape of labels: {training_labels.shape}")
print(f"type of labels: {type(training_labels)}")
# Dataframe for labels
labels = training_labels.flatten()
df_labels = pd.DataFrame(labels, columns=['label'])
print(df_labels.head())
# Out:
# Shape of images: (11943, 96, 96, 3)
# type of images: <class 'numpy.ndarray'>
# shape of labels: (11943, 1)
# type of labels: <class 'numpy.ndarray'>
#    label
# 0      7
# 1      3
# 2      6
# 3      6
# 4      7

# %%
# train test val split

from sklearn.model_selection import train_test_split

# Define split sizes
test_size = 0.2        # 20% for test
validation_size = 0.2  # 20% of the remaining 80% = 16% for validation

# Split into (training+validation) and test sets
training_labels = training_labels.flatten()
X_train_val, X_test, y_train_val, y_test = train_test_split(
    training_images,
    training_labels,
    test_size=test_size,
    random_state=42,
    stratify=training_labels
)

# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    test_size=validation_size,
    random_state=42,
    stratify=y_train_val
)
print("Training Images - Min pixel value:", np.min(X_train))
print("Training Images - Max pixel value:", np.max(X_train))
print("Validation Images - Min pixel value:", np.min(X_val))
print("Validation Images - Max pixel value:", np.max(X_val))
print("Test Images - Min pixel value:", np.min(X_test))
print("Test Images - Max pixel value:", np.max(X_test))
print("-----------------------------------------------------")
print(f"Training set shape: {X_train.shape}, {y_train.shape}")
print(f"Validation set shape: {X_val.shape}, {y_val.shape}")
print(f"Test set shape: {X_test.shape}, {y_test.shape}")
# Out:
# Training Images - Min pixel value: 0
# Training Images - Max pixel value: 255
# Validation Images - Min pixel value: 0
# Validation Images - Max pixel value: 255
# Test Images - Min pixel value: 0
# Test Images - Max pixel value: 255
# -----------------------------------------------------
# Training set shape: (7643, 96, 96, 3), (7643,)
# Validation set shape: (1911, 96, 96, 3), (1911,)
# Test set shape: (2389, 96, 96, 3), (2389,)

# %%
#class_counts = np.bincount(training_labels)
class_counts = pd.Series(y_train).value_counts()  # Use only y_train, not the full label set

# `class_counts` now contains the size of each class:
# - `class_counts[j]` gives the count of items with class label `j`.

max_count = class_counts.max()
print(f"Maximum class count: {max_count}")

# Initialize lists to hold oversampled data
X_train_oversampled = []
y_train_oversampled = []

# Iterate through each class to perform oversampling
for class_label in class_counts.index:
    # Current class samples
    X_class = X_train[y_train == class_label]
    y_class = y_train[y_train == class_label]

    # Number of samples to add
    samples_needed = max_count - len(X_class)

    if samples_needed > 0:
        # Calculate how many times to duplicate the class samples
        duplicates = samples_needed // len(X_class)
        remainder = samples_needed % len(X_class)

        # Duplicate the entire class as many times as needed
        for _ in range(duplicates):
            X_train_oversampled.append(X_class)
            y_train_oversampled.append(y_class)

        # Add the remaining samples by randomly selecting from the class
        if remainder > 0:
            indices = np.random.choice(len(X_class), size=remainder, replace=True)
            X_train_oversampled.append(X_class[indices])
            y_train_oversampled.append(y_class[indices])

# Concatenate the oversampled data
if X_train_oversampled:
    X_train_oversampled = np.vstack(X_train_oversampled)
    y_train_oversampled = np.hstack(y_train_oversampled)

    # Append the oversampled data to the original training set
    X_train_balanced = np.vstack((X_train, X_train_oversampled))
    y_train_balanced = np.hstack((y_train, y_train_oversampled))
else:
    # If no oversampling is needed
    X_train_balanced = X_train
    y_train_balanced = y_train

print(f"Training set shape after oversampling: {X_train_balanced.shape}, {y_train_balanced.shape}")
# Out:
# Maximum class count: 1491
# Training set shape after oversampling: (11928, 96, 96, 3), (11928,)

# %%
import tensorflow as tf
import keras_cv

# Define the augmentation pipeline
augmentation_pipeline = keras_cv.layers.Augmenter([
    keras_cv.layers.RandomSaturation(factor=(0, 1.0)),
    keras_cv.layers.RandomSharpness(factor=(0, 1.0), value_range=[0, 255]),
    keras_cv.layers.RandomShear(
        x_factor=0.3,
        y_factor=0.3,
        interpolation="bilinear",
        fill_mode="reflect",
        fill_value=0.0),
    keras_cv.layers.Solarization(value_range=[0, 255])
])

# Function to apply augmentations
def augment_image(image, label):
    # Convert TensorFlow tensors to NumPy arrays
    image = image.numpy()  # Convert to NumPy for manipulation
    label = label.numpy()  # Convert to NumPy for manipulation

    # Ensure the image is in uint8 format using NumPy
    if image.dtype != np.uint8:
        image = (image * 255).astype(np.uint8)

    # Apply augmentation directly using the Keras CV pipeline
    image = augmentation_pipeline(image)  # Augmentation is directly applied here

    # Convert back to float32 and normalize using TensorFlow operations
    image = tf.cast(image, tf.float32) / 255.0  # Convert to float32 using tf.cast
    image = (image - tf.constant([0.485, 0.456, 0.406])) / tf.constant([0.229, 0.224, 0.225])

    # Ensure label is int32 using tf.cast
    label = tf.cast(label, tf.int32)

    return image, label

# Wrapper function for TensorFlow
def tf_augment_image(image, label):
    # Apply the augment_image function using tf.py_function
    augmented_image, augmented_label = tf.py_function(
        func=augment_image,
        inp=[image, label],
        Tout=[tf.float32, tf.int32]  # Corrected label type to int32
    )

    # Set the shape information
    augmented_image.set_shape((96, 96, 3))
    augmented_label.set_shape(())

    return augmented_image, augmented_label

#print(y_train_balanced.dtype)
#y_train_balanced = y_train_balanced.reshape(-1).astype(np.int32)
#print(y_train_balanced.dtype)

# Create TensorFlow Dataset from balanced training data
train_dataset = tf.data.Dataset.from_tensor_slices((X_train_balanced, y_train_balanced))

# Apply the augmentation to the training dataset
train_dataset = train_dataset.map(
    tf_augment_image,
    num_parallel_calls=tf.data.AUTOTUNE
)

# Shuffle, batch, and prefetch for performance
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
# Check the shape of the training dataset and the pixel values
def inspect_training_dataset(dataset):
    # Take a batch from the dataset
    batch = next(iter(dataset))

    # Extract the images from the batch
    images, labels = batch

    # Print the shape of the images and labels
    print(f"Shape of images batch: {images.shape}")
    print(f"Shape of labels batch: {labels.shape}")

    # Print the pixel values of the first image in the batch
    first_image = images[0].numpy()
    print(f"Pixel values of the first image (after augmentation):")
    print(first_image.max(), first_image.min())

# Call the function to inspect the training dataset
inspect_training_dataset(train_dataset)
# Out:
# Shape of images batch: (32, 96, 96, 3)
# Shape of labels batch: (32,)
# Pixel values of the first image (after augmentation):
# 2.4285715 -2.117904

# %%
# Function to plot a few augmented images
def plot_augmented_images(dataset, num_images=9):
    # Take a batch from the dataset
    batch = next(iter(dataset))

    # Extract the images and labels from the batch
    images, labels = batch

    # Set up the plot (e.g., 3x3 grid)
    fig, axes = plt.subplots(3, 3, figsize=(12, 12))  # 3x3 grid for 9 images
    axes = axes.ravel()  # Flatten the 2D array of axes

    # Plot each image
    for i in range(num_images):
        image = images[i].numpy()  # Convert tensor to numpy array for plotting

        # Reverse normalization for proper display
        image = (image * np.array([0.229, 0.224, 0.225])) + np.array([0.485, 0.456, 0.406])
        image = np.clip(image, 0, 1)  # Ensure the pixel values are within [0, 1]

        # Plot the image
        axes[i].imshow(image)
        axes[i].axis('off')  # Hide axes
        axes[i].set_title(f"Label: {labels[i].numpy()}")  # Show the label

    plt.tight_layout()
    plt.show()

# Call the function to plot the augmented images
plot_augmented_images(train_dataset)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input
from tensorflow.keras import mixed_precision
import matplotlib.pyplot as plt
import numpy as np

# Enable mixed precision ?
#policy = mixed_precision.Policy('float32')
#mixed_precision.set_global_policy(policy)

# requirements for inceptionresnetv2
input_shape = (299, 299, 3)
inputs = layers.Input(shape=input_shape)

base_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=input_shape)

# Freeze
base_model.trainable = False

# only gap and dense classifier
x = base_model(inputs)
x = layers.GlobalAveragePooling2D()(x)  #
outputs = layers.Dense(8, activation='softmax', dtype='float32')(x)  # 8 classes

model = models.Model(inputs, outputs)

model.summary()

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

model_checkpoint = callbacks.ModelCheckpoint(
    'best_inception_resnet_model.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min'
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

callback_list = [early_stop, model_checkpoint, reduce_lr]

def preprocess(image, label):
    image = tf.image.resize(image, [299, 299])
    image = tf.cast(image, tf.float32)
    image = preprocess_input(image)  # InceptionResNetV2's preprocess_input, does this normalize automatically?
    label = tf.cast(label, tf.int32)
    return image, label

batch_size = 128
train_dataset = tf.data.Dataset.from_tensor_slices((X_train_balanced, y_train_balanced))
train_dataset = train_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
val_dataset = val_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Train the model
epochs = 300
history = model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=val_dataset,
    callbacks=callback_list,
)


plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')


plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 299, 299, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_resnet_v2 (Functional)     │ (None, 8, 8, 1536)          │      54,336,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1536)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │          12,296 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 54,349,032 (207.33 MB)
#  Trainable params: 12,296 (48.03 KB)
#  Non-trainable params: 54,336,736 (207.28 MB)
# Epoch 1/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 89s 573ms/step - accuracy: 0.4458 - loss: 1.6112 - val_accuracy: 0.1277 - val_loss: 4.7920 - learning_rate: 0.0010
# Epoch 2/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.4374 - loss: 2.4659 - val_accuracy: 0.1570 - val_loss: 3.9002 - learning_rate: 0.0010
# Epoch 3/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.4923 - loss: 1.9253 - val_accuracy: 0.1894 - val_loss: 3.3718 - learning_rate: 0.0010
# Epoch 4/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.5345 - loss: 1.6660 - val_accuracy: 0.2282 - val_loss: 2.9982 - learning_rate: 0.0010
# Epoch 5/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.5680 - loss: 1.4888 - val_accuracy: 0.2737 - val_loss: 2.7218 - learning_rate: 0.0010
# Epoch 6/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.5991 - loss: 1.3587 - val_accuracy: 0.3077 - val_loss: 2.5060 - learning_rate: 0.0010
# Epoch 7/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.6274 - loss: 1.2569 - val_accuracy: 0.3354 - val_loss: 2.3316 - learning_rate: 0.0010
# Epoch 8/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.6514 - loss: 1.1741 - val_accuracy: 0.3600 - val_loss: 2.1878 - learning_rate: 0.0010
# Epoch 9/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 183ms/step - accuracy: 0.6700 - loss: 1.1052 - val_accuracy: 0.3904 - val_loss: 2.0676 - learning_rate: 0.0010
# Epoch 10/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.6832 - loss: 1.0468 - val_accuracy: 0.4129 - val_loss: 1.9652 - learning_rate: 0.0010
# Epoch 11/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.6976 - loss: 0.9965 - val_accuracy: 0.4349 - val_loss: 1.8773 - learning_rate: 0.0010
# Epoch 12/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.7109 - loss: 0.9527 - val_accuracy: 0.4574 - val_loss: 1.8013 - learning_rate: 0.0010
# Epoch 13/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7203 - loss: 0.9141 - val_accuracy: 0.4725 - val_loss: 1.7347 - learning_rate: 0.0010
# Epoch 14/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.7303 - loss: 0.8798 - val_accuracy: 0.4840 - val_loss: 1.6759 - learning_rate: 0.0010
# Epoch 15/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.7405 - loss: 0.8492 - val_accuracy: 0.4976 - val_loss: 1.6238 - learning_rate: 0.0010
# Epoch 16/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7459 - loss: 0.8216 - val_accuracy: 0.5107 - val_loss: 1.5774 - learning_rate: 0.0010
# Epoch 17/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.7530 - loss: 0.7966 - val_accuracy: 0.5217 - val_loss: 1.5354 - learning_rate: 0.0010
# Epoch 18/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.7589 - loss: 0.7737 - val_accuracy: 0.5332 - val_loss: 1.4974 - learning_rate: 0.0010
# Epoch 19/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.7655 - loss: 0.7528 - val_accuracy: 0.5411 - val_loss: 1.4633 - learning_rate: 0.0010
# Epoch 20/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.7707 - loss: 0.7335 - val_accuracy: 0.5495 - val_loss: 1.4320 - learning_rate: 0.0010
# Epoch 21/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.7764 - loss: 0.7157 - val_accuracy: 0.5578 - val_loss: 1.4031 - learning_rate: 0.0010
# Epoch 22/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7822 - loss: 0.6991 - val_accuracy: 0.5651 - val_loss: 1.3766 - learning_rate: 0.0010
# Epoch 23/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7873 - loss: 0.6837 - val_accuracy: 0.5746 - val_loss: 1.3525 - learning_rate: 0.0010
# Epoch 24/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.7913 - loss: 0.6693 - val_accuracy: 0.5808 - val_loss: 1.3299 - learning_rate: 0.0010
# Epoch 25/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.7942 - loss: 0.6557 - val_accuracy: 0.5845 - val_loss: 1.3088 - learning_rate: 0.0010
# Epoch 26/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.7989 - loss: 0.6430 - val_accuracy: 0.5918 - val_loss: 1.2892 - learning_rate: 0.0010
# Epoch 27/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8027 - loss: 0.6310 - val_accuracy: 0.5981 - val_loss: 1.2707 - learning_rate: 0.0010
# Epoch 28/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - accuracy: 0.8068 - loss: 0.6196 - val_accuracy: 0.6028 - val_loss: 1.2536 - learning_rate: 0.0010
# Epoch 29/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.8103 - loss: 0.6088 - val_accuracy: 0.6075 - val_loss: 1.2374 - learning_rate: 0.0010
# Epoch 30/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8141 - loss: 0.5986 - val_accuracy: 0.6112 - val_loss: 1.2221 - learning_rate: 0.0010
# Epoch 31/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8174 - loss: 0.5888 - val_accuracy: 0.6175 - val_loss: 1.2075 - learning_rate: 0.0010
# Epoch 32/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8199 - loss: 0.5795 - val_accuracy: 0.6222 - val_loss: 1.1941 - learning_rate: 0.0010
# Epoch 33/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8226 - loss: 0.5707 - val_accuracy: 0.6269 - val_loss: 1.1808 - learning_rate: 0.0010
# Epoch 34/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.8248 - loss: 0.5622 - val_accuracy: 0.6306 - val_loss: 1.1686 - learning_rate: 0.0010
# Epoch 35/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8274 - loss: 0.5540 - val_accuracy: 0.6342 - val_loss: 1.1568 - learning_rate: 0.0010
# Epoch 36/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8295 - loss: 0.5462 - val_accuracy: 0.6379 - val_loss: 1.1456 - learning_rate: 0.0010
# Epoch 37/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8316 - loss: 0.5387 - val_accuracy: 0.6389 - val_loss: 1.1345 - learning_rate: 0.0010
# Epoch 38/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8337 - loss: 0.5314 - val_accuracy: 0.6400 - val_loss: 1.1240 - learning_rate: 0.0010
# Epoch 39/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.8350 - loss: 0.5244 - val_accuracy: 0.6410 - val_loss: 1.1139 - learning_rate: 0.0010
# Epoch 40/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8370 - loss: 0.5177 - val_accuracy: 0.6436 - val_loss: 1.1044 - learning_rate: 0.0010
# Epoch 41/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8380 - loss: 0.5112 - val_accuracy: 0.6484 - val_loss: 1.0950 - learning_rate: 0.0010
# Epoch 42/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8395 - loss: 0.5048 - val_accuracy: 0.6515 - val_loss: 1.0858 - learning_rate: 0.0010
# Epoch 43/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8419 - loss: 0.4987 - val_accuracy: 0.6546 - val_loss: 1.0769 - learning_rate: 0.0010
# Epoch 44/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8432 - loss: 0.4927 - val_accuracy: 0.6572 - val_loss: 1.0686 - learning_rate: 0.0010
# Epoch 45/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 184ms/step - accuracy: 0.8450 - loss: 0.4870 - val_accuracy: 0.6609 - val_loss: 1.0601 - learning_rate: 0.0010
# Epoch 46/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8468 - loss: 0.4813 - val_accuracy: 0.6651 - val_loss: 1.0519 - learning_rate: 0.0010
# Epoch 47/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.8486 - loss: 0.4758 - val_accuracy: 0.6667 - val_loss: 1.0440 - learning_rate: 0.0010
# Epoch 48/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8492 - loss: 0.4705 - val_accuracy: 0.6719 - val_loss: 1.0362 - learning_rate: 0.0010
# Epoch 49/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8511 - loss: 0.4653 - val_accuracy: 0.6740 - val_loss: 1.0285 - learning_rate: 0.0010
# Epoch 50/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.8538 - loss: 0.4602 - val_accuracy: 0.6750 - val_loss: 1.0214 - learning_rate: 0.0010
# Epoch 51/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8555 - loss: 0.4552 - val_accuracy: 0.6761 - val_loss: 1.0140 - learning_rate: 0.0010
# Epoch 52/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.8563 - loss: 0.4503 - val_accuracy: 0.6787 - val_loss: 1.0073 - learning_rate: 0.0010
# Epoch 53/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.8570 - loss: 0.4456 - val_accuracy: 0.6808 - val_loss: 1.0002 - learning_rate: 0.0010
# Epoch 54/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.
300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.9472 - loss: 0.1591 - val_accuracy: 0.8294 - val_loss: 0.5613 - learning_rate: 0.0010
# Epoch 186/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9480 - loss: 0.1581 - val_accuracy: 0.8299 - val_loss: 0.5595 - learning_rate: 0.0010
# Epoch 187/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9485 - loss: 0.1570 - val_accuracy: 0.8305 - val_loss: 0.5580 - learning_rate: 0.0010
# Epoch 188/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9486 - loss: 0.1560 - val_accuracy: 0.8305 - val_loss: 0.5560 - learning_rate: 0.0010
# Epoch 189/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9490 - loss: 0.1549 - val_accuracy: 0.8305 - val_loss: 0.5546 - learning_rate: 0.0010
# Epoch 190/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 183ms/step - accuracy: 0.9498 - loss: 0.1539 - val_accuracy: 0.8315 - val_loss: 0.5526 - learning_rate: 0.0010
# Epoch 191/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9499 - loss: 0.1529 - val_accuracy: 0.8320 - val_loss: 0.5514 - learning_rate: 0.0010
# Epoch 192/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9502 - loss: 0.1519 - val_accuracy: 0.8325 - val_loss: 0.5493 - learning_rate: 0.0010
# Epoch 193/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9504 - loss: 0.1508 - val_accuracy: 0.8336 - val_loss: 0.5479 - learning_rate: 0.0010
# Epoch 194/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9505 - loss: 0.1499 - val_accuracy: 0.8341 - val_loss: 0.5461 - learning_rate: 0.0010
# Epoch 195/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9507 - loss: 0.1489 - val_accuracy: 0.8341 - val_loss: 0.5444 - learning_rate: 0.0010
# Epoch 196/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.9512 - loss: 0.1479 - val_accuracy: 0.8341 - val_loss: 0.5425 - learning_rate: 0.0010
# Epoch 197/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9518 - loss: 0.1469 - val_accuracy: 0.8346 - val_loss: 0.5414 - learning_rate: 0.0010
# Epoch 198/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9524 - loss: 0.1459 - val_accuracy: 0.8352 - val_loss: 0.5396 - learning_rate: 0.0010
# Epoch 199/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9530 - loss: 0.1450 - val_accuracy: 0.8352 - val_loss: 0.5381 - learning_rate: 0.0010
# Epoch 200/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9533 - loss: 0.1440 - val_accuracy: 0.8362 - val_loss: 0.5365 - learning_rate: 0.0010
# Epoch 201/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.9533 - loss: 0.1431 - val_accuracy: 0.8362 - val_loss: 0.5353 - learning_rate: 0.0010
# Epoch 202/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9536 - loss: 0.1422 - val_accuracy: 0.8367 - val_loss: 0.5338 - learning_rate: 0.0010
# Epoch 203/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9542 - loss: 0.1413 - val_accuracy: 0.8367 - val_loss: 0.5319 - learning_rate: 0.0010
# Epoch 204/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9545 - loss: 0.1403 - val_accuracy: 0.8378 - val_loss: 0.5302 - learning_rate: 0.0010
# Epoch 205/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9546 - loss: 0.1394 - val_accuracy: 0.8378 - val_loss: 0.5288 - learning_rate: 0.0010
# Epoch 206/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.9550 - loss: 0.1385 - val_accuracy: 0.8378 - val_loss: 0.5276 - learning_rate: 0.0010
# Epoch 207/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9550 - loss: 0.1376 - val_accuracy: 0.8388 - val_loss: 0.5259 - learning_rate: 0.0010
# Epoch 208/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9554 - loss: 0.1367 - val_accuracy: 0.8394 - val_loss: 0.5244 - learning_rate: 0.0010
# Epoch 209/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9554 - loss: 0.1359 - val_accuracy: 0.8394 - val_loss: 0.5231 - learning_rate: 0.0010
# Epoch 210/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9560 - loss: 0.1350 - val_accuracy: 0.8394 - val_loss: 0.5215 - learning_rate: 0.0010
# Epoch 211/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 183ms/step - accuracy: 0.9564 - loss: 0.1341 - val_accuracy: 0.8394 - val_loss: 0.5202 - learning_rate: 0.0010
# Epoch 212/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9568 - loss: 0.1333 - val_accuracy: 0.8399 - val_loss: 0.5190 - learning_rate: 0.0010
# Epoch 213/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9571 - loss: 0.1324 - val_accuracy: 0.8404 - val_loss: 0.5171 - learning_rate: 0.0010
# Epoch 214/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9576 - loss: 0.1315 - val_accuracy: 0.8414 - val_loss: 0.5160 - learning_rate: 0.0010
# Epoch 215/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9580 - loss: 0.1307 - val_accuracy: 0.8414 - val_loss: 0.5146 - learning_rate: 0.0010
# Epoch 216/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.9585 - loss: 0.1299 - val_accuracy: 0.8420 - val_loss: 0.5130 - learning_rate: 0.0010
# Epoch 217/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9592 - loss: 0.1291 - val_accuracy: 0.8420 - val_loss: 0.5118 - learning_rate: 0.0010
# Epoch 218/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9604 - loss: 0.1283 - val_accuracy: 0.8420 - val_loss: 0.5109 - learning_rate: 0.0010
# Epoch 219/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9610 - loss: 0.1275 - val_accuracy: 0.8425 - val_loss: 0.5092 - learning_rate: 0.0010
# Epoch 220/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9610 - loss: 0.1267 - val_accuracy: 0.8430 - val_loss: 0.5078 - learning_rate: 0.0010
# Epoch 221/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.9614 - loss: 0.1258 - val_accuracy: 0.8441 - val_loss: 0.5066 - learning_rate: 0.0010
# Epoch 222/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9616 - loss: 0.1251 - val_accuracy: 0.8441 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 223/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9617 - loss: 0.1243 - val_accuracy: 0.8456 - val_loss: 0.5040 - learning_rate: 0.0010
# Epoch 224/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9619 - loss: 0.1235 - val_accuracy: 0.8467 - val_loss: 0.5027 - learning_rate: 0.0010
# Epoch 225/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9620 - loss: 0.1228 - val_accuracy: 0.8467 - val_loss: 0.5014 - learning_rate: 0.0010
# Epoch 226/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.9620 - loss: 0.1220 - val_accuracy: 0.8477 - val_loss: 0.5002 - learning_rate: 0.0010
# Epoch 227/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9624 - loss: 0.1212 - val_accuracy: 0.8482 - val_loss: 0.4989 - learning_rate: 0.0010
# Epoch 228/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9626 - loss: 0.1205 - val_accuracy: 0.8488 - val_loss: 0.4977 - learning_rate: 0.0010
# Epoch 229/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9627 - loss: 0.1198 - val_accuracy: 0.8488 - val_loss: 0.4965 - learning_rate: 0.0010
# Epoch 230/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9630 - loss: 0.1190 - val_accuracy: 0.8488 - val_loss: 0.4951 - learning_rate: 0.0010
# Epoch 231/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9632 - loss: 0.1183 - val_accuracy: 0.8493 - val_loss: 0.4943 - learning_rate: 0.0010
# Epoch 232/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.9638 - loss: 0.1176 - val_accuracy: 0.8503 - val_loss: 0.4930 - learning_rate: 0.0010
# Epoch 233/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9641 - loss: 0.1169 - val_accuracy: 0.8503 - val_loss: 0.4917 - learning_rate: 0.0010
# Epoch 234/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9641 - loss: 0.1161 - val_accuracy: 0.8503 - val_loss: 0.4906 - learning_rate: 0.0010
# Epoch 235/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9647 - loss: 0.1154 - val_accuracy: 0.8503 - val_loss: 0.4895 - learning_rate: 0.0010
# Epoch 236/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9647 - loss: 0.1147 - val_accuracy: 0.8509 - val_loss: 0.4884 - learning_rate: 0.0010
# Epoch 237/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 183ms/step - accuracy: 0.9649 - loss: 0.1140 - val_accuracy: 0.8514 - val_loss: 0.4873 - learning_rate: 0.0010
# Epoch 238/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.
300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - accuracy: 0.9742 - loss: 0.0834 - val_accuracy: 0.8681 - val_loss: 0.4414 - learning_rate: 0.0010
# Epoch 292/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9742 - loss: 0.0829 - val_accuracy: 0.8687 - val_loss: 0.4407 - learning_rate: 0.0010
# Epoch 293/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - accuracy: 0.9746 - loss: 0.0824 - val_accuracy: 0.8687 - val_loss: 0.4404 - learning_rate: 0.0010
# Epoch 294/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - accuracy: 0.9746 - loss: 0.0820 - val_accuracy: 0.8692 - val_loss: 0.4395 - learning_rate: 0.0010
# Epoch 295/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9746 - loss: 0.0816 - val_accuracy: 0.8692 - val_loss: 0.4389 - learning_rate: 0.0010
# Epoch 296/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - accuracy: 0.9749 - loss: 0.0811 - val_accuracy: 0.8697 - val_loss: 0.4387 - learning_rate: 0.0010
# Epoch 297/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9751 - loss: 0.0807 - val_accuracy: 0.8697 - val_loss: 0.4377 - learning_rate: 0.0010
# Epoch 298/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9751 - loss: 0.0802 - val_accuracy: 0.8697 - val_loss: 0.4373 - learning_rate: 0.0010
# Epoch 299/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - accuracy: 0.9753 - loss: 0.0798 - val_accuracy: 0.8702 - val_loss: 0.4367 - learning_rate: 0.0010
# Epoch 300/300
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - accuracy: 0.9756 - loss: 0.0794 - val_accuracy: 0.8702 - val_loss: 0.4361 - learning_rate: 0.0010

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_dataset = test_dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 844ms/step - accuracy: 0.8601 - loss: 0.5059
# Test Loss: 0.48828911781311035
# Test Accuracy: 0.8689828515052795

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Step 1: Generate Predictions
y_pred = model.predict(test_dataset)
y_pred_labels = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Step 2: Calculate the Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_labels)

# Step 3: Plot the Confusion Matrix
plt.figure(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=range(8))  # Assuming 8 classes
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 21s 627ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow.keras as tfk

def plot_image_with_prediction(image, model, class_names):
    # Preprocess the image for model prediction
    preprocessed_image = tf.image.resize(image, (299, 299))  # resize for InceptionResNetV2
    preprocessed_image = tf.expand_dims(preprocessed_image, axis=0)  # add batch dimension
    preprocessed_image = tf.keras.applications.inception_resnet_v2.preprocess_input(preprocessed_image)

    # Get prediction probabilities
    prediction = model.predict(preprocessed_image)[0]

    # Set up the plot
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Plot the image
    axes[0].imshow(image / 255.0)  # Assuming image is in uint8 format
    axes[0].axis('off')
    axes[0].set_title("Input Image")

    # Plot the prediction probabilities as a bar chart
    bar_positions = np.arange(len(class_names))
    axes[1].barh(bar_positions, prediction, align='center')
    axes[1].set_yticks(bar_positions)
    axes[1].set_yticklabels(class_names)
    axes[1].invert_yaxis()  # Highest probability at the top
    axes[1].set_xlabel("Prediction Probability")
    axes[1].set_title("Prediction Probabilities")

    plt.tight_layout()
    plt.show()

#
image = X_test[1]
model = tfk.models.load_model('AUGMENTED_NOE.keras')
class_names = ["0", "1", "2", "3", "4", "5", "6", "7"]
plot_image_with_prediction(image, model, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step

# %% [markdown]
# ## To save :

# %%
model.save('weights.keras')
del model

# %%
# %%writefile model.py
import numpy as np

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl


class Model:
    def __init__(self):
        """
        Initialize the internal state of the model. Note that the __init__
        method cannot accept any arguments.

        The following is an example loading the weights of a pre-trained
        model.
        """
        self.neural_network = tfk.models.load_model('weights.keras')

    def predict(self, X):
        """
        Predict the labels corresponding to the input X. Note that X is a numpy
        array of shape (n_samples, 96, 96, 3) and the output should be a numpy
        array of shape (n_samples,). Therefore, outputs must no be one-hot
        encoded.

        The following is an example of a prediction from the pre-trained model
        loaded in the __init__ method.
        """
        X /= 255.0
        preds = self.neural_network.predict(X)
        if len(preds.shape) == 2:
            preds = np.argmax(preds, axis=1)
        return preds
# Out:
# Overwriting model.py
